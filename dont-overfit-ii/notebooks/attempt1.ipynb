# %%
import pandas as pd
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
train.describe()
# Out:
#                id      target           0           1           2           3  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean   124.500000    0.640000    0.023292   -0.026872    0.167404    0.001904
# std     72.312977    0.480963    0.998354    1.009314    1.021709    1.011751
# min      0.000000    0.000000   -2.319000   -2.931000   -2.477000   -2.359000
# 25%     62.250000    0.000000   -0.644750   -0.739750   -0.425250   -0.686500
# 50%    124.500000    1.000000   -0.015500    0.057000    0.184000   -0.016500
# 75%    186.750000    1.000000    0.677000    0.620750    0.805000    0.720000
# max    249.000000    1.000000    2.567000    2.419000    3.392000    2.771000
#
#                 4           5           6           7     ...             290  \
# count  250.000000  250.000000  250.000000  250.000000     ...      250.000000
# mean     0.001588   -0.007304    0.032052    0.078412     ...        0.044652
# ...

# %%
X_train = train.iloc[:,2:]
y_train = train.iloc[:,1]
y_test = test.iloc[:,1:]

# %%
clf = LogisticRegression(class_weight='balanced', penalty='l1', C=0.1, solver='liblinear').fit(X_train, y_train)

# %%
predicts = clf.predict(X_train)
np.sqrt((predicts - y_train.values)*(predicts - y_train.values)).sum()/len(predicts)
# Out:
# 0.128

# %%
test_predicts = clf.predict(y_test)
test_predicts = pd.DataFrame(test_predicts, columns=['target'])

# %%
test_predicts['id'] = test['id']

# %%
test_predicts.to_csv('submission.csv', index=False)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=8, min_samples_leaf=2, max_features=5)
clf = clf.fit(X_train,y_train)
predicts = clf.predict(X_train)
np.sqrt((predicts - y_train.values)*(predicts - y_train.values)).sum()/len(predicts)
# Out:
# 0.104

# %%
test_predicts = clf.predict(y_test)
test_predicts = pd.DataFrame(test_predicts, columns=['target'])
test_predicts['id'] = test['id']
test_predicts.to_csv('submission.csv', index=False)
